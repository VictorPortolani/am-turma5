# %% [markdown]
# <a href="https://colab.research.google.com/github/VictorPortolani/am-turma5/blob/main/am_turma5_aula0804.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def soma(a,b):
  return(a + b)
print(soma(26,512))
# Out:
# 538

# %% [markdown]
# # Pipeline | Python Básico

# %%
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install seaborn

# %%
pessoas = ('Homo Sapiens', 'Canis Familiaris', 'Felis Catus')
print(type(pessoas))
print(pessoas)
pessoas[0]
pessoas.index('Felis Catus')
# Out:
# <class 'tuple'>
# ('Homo Sapiens', 'Canis Familiarris', 'Felis Catus')
# 2

# %%
for elemento in pessoas:
  print("Classe Biológica: ",elemento)
# Out:
# Classe Biológica:  Homo Sapiens
# Classe Biológica:  Canis Familiarris
# Classe Biológica:  Felis Catus

# %%
classes = [{'homoeretus':'AC023'}, {'Canis Familiaris':'AC028'}, {'Aluroponda Melanoleuca': 'AC012'}]
classes
# Out:
# [{'homoeretus': 'AC023'},
#  {'Canis Familiaris': 'AC028'},
#  {'Aluroponda Melanoleuca': 'AC012'}]
